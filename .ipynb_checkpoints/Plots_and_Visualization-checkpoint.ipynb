# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import datetime as datetime
from matplotlib import dates
import seaborn as sns

# %%
#import csv file for Site Openness and Snow Disappearance
results = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\GapFraction_SDD.csv")

#make sure all dates are type datetime
results['SDD1'] = pd.to_datetime(results['SDD1'])
results['SDD2'] = pd.to_datetime(results['SDD2'])
results['SDD3'] = pd.to_datetime(results['SDD3'])
results['SDD4'] = pd.to_datetime(results['SDD4'])
results['SDD5'] = pd.to_datetime(results['SDD5'])
results['SDD6'] = pd.to_datetime(results['SDD6'])
results['SDD7'] = pd.to_datetime(results['SDD7'])
results['SDD8'] = pd.to_datetime(results['SDD8'])
results['SDD9'] = pd.to_datetime(results['SDD9'])

#create variables containing results for north and south respectively
CNresults = results.loc[results['Site'] == "CN"]
CSresults = results.loc[results['Site'] == "CS"]

# %%
#import csv files for snow depth
CN20 = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CN-20ProcessedData.csv")
CN50 = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CN-50ProcessedData.csv")
CN60 = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CN-60ProcessedData.csv")
CN70 = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CN-70ProcessedData.csv")
CNG = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CN-GProcessedData.csv")
CNF = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CN-FProcessedData.csv")

CS20 = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CS-20ProcessedData.csv")
CS50 = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CS-50ProcessedData.csv")
CS60 = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CS-60ProcessedData.csv")
CS120 = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CS-120ProcessedData.csv")
CSG = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CS-GProcessedData.csv")
CSF = pd.read_csv("C:\\Users\\johnc\\Desktop\\CER\\ProcessedCameraData(csv)\\ProcessedCameraData\\CS-FProcessedData.csv")

# make sure all date's are type datetime
CNG['Date'] = pd.to_datetime(CNG['Date'])
CNF['Date'] = pd.to_datetime(CNF['Date'])
CN20['Date'] = pd.to_datetime(CN20['Date'])
CN50['Date'] = pd.to_datetime(CN50['Date'])
CN60['Date'] = pd.to_datetime(CN60['Date'])
CN70['Date'] = pd.to_datetime(CN70['Date'])

CSG['Date'] = pd.to_datetime(CSG['Date'])
CSF['Date'] = pd.to_datetime(CSF['Date'])
CS20['Date'] = pd.to_datetime(CS20['Date'])
CS50['Date'] = pd.to_datetime(CS50['Date'])
CS60['Date'] = pd.to_datetime(CS60['Date'])
CS120['Date'] = pd.to_datetime(CS120['Date'])

# %%
#Calculate statistics for snow depth
CNF['Median_depth'] = CNF[["Pole1","Pole2","Pole3"]].median(axis=1)
CNF['Maximum_depth'] = CNF[["Pole1","Pole2","Pole3"]].max(axis=1)
CNF['Minimum_depth'] = CNF[["Pole1","Pole2","Pole3"]].min(axis=1)
CNG['Median_depth'] = CNG[["Pole1","Pole2","Pole3"]].median(axis=1)
CNG['Maximum_depth'] = CNG[["Pole1","Pole2","Pole3"]].max(axis=1)
CNG['Minimum_depth'] = CNG[["Pole1","Pole2","Pole3"]].min(axis=1)
CN20['Median_depth'] = CN20[["Pole1","Pole2","Pole3"]].median(axis=1)
CN20['Maximum_depth'] = CN20[["Pole1","Pole2","Pole3"]].max(axis=1)
CN20['Minimum_depth'] = CN20[["Pole1","Pole2","Pole3"]].min(axis=1)
CN50['Median_depth'] = CN50[["Pole1","Pole2","Pole3"]].median(axis=1)
CN50['Maximum_depth'] = CN50[["Pole1","Pole2","Pole3"]].max(axis=1)
CN50['Minimum_depth'] = CN50[["Pole1","Pole2","Pole3"]].min(axis=1)
CN60['Median_depth'] = CN60[["Pole1","Pole2","Pole3"]].median(axis=1)
CN60['Maximum_depth'] = CN60[["Pole1","Pole2","Pole3"]].max(axis=1)
CN60['Minimum_depth'] = CN60[["Pole1","Pole2","Pole3"]].min(axis=1)
CN70['Median_depth'] = CN70[["Pole1","Pole2","Pole3"]].median(axis=1)
CN70['Maximum_depth'] = CN70[["Pole1","Pole2","Pole3"]].max(axis=1)
CN70['Minimum_depth'] = CN70[["Pole1","Pole2","Pole3"]].min(axis=1)
CSF['Median_depth'] = CSF[["Pole1","Pole2","Pole3"]].median(axis=1)
CSF['Maximum_depth'] = CSF[["Pole1","Pole2","Pole3"]].max(axis=1)
CSF['Minimum_depth'] = CSF[["Pole1","Pole2","Pole3"]].min(axis=1)
CSG['Median_depth'] = CSG[["Pole1","Pole2","Pole3"]].median(axis=1)
CSG['Maximum_depth'] = CSG[["Pole1","Pole2","Pole3"]].max(axis=1)
CSG['Minimum_depth'] = CSG[["Pole1","Pole2","Pole3"]].min(axis=1)
CS20['Median_depth'] = CS20[["Pole1","Pole2","Pole3"]].median(axis=1)
CS20['Maximum_depth'] = CS20[["Pole1","Pole2","Pole3"]].max(axis=1)
CS20['Minimum_depth'] = CS20[["Pole1","Pole2","Pole3"]].min(axis=1)
CS50['Median_depth'] = CS50[["Pole1","Pole2","Pole3"]].median(axis=1)
CS50['Maximum_depth'] = CS50[["Pole1","Pole2","Pole3"]].max(axis=1)
CS50['Minimum_depth'] = CS50[["Pole1","Pole2","Pole3"]].min(axis=1)
CS60['Median_depth'] = CS60[["Pole1","Pole2","Pole3"]].median(axis=1)
CS60['Maximum_depth'] = CS60[["Pole1","Pole2","Pole3"]].max(axis=1)
CS60['Minimum_depth'] = CS60[["Pole1","Pole2","Pole3"]].min(axis=1)
CS120['Median_depth'] = CS120[["Pole1","Pole2","Pole3"]].median(axis=1)
CS120['Maximum_depth'] = CS120[["Pole1","Pole2","Pole3"]].max(axis=1)
CS120['Minimum_depth'] = CS120[["Pole1","Pole2","Pole3"]].min(axis=1)

# %%
#code to graph snow depth at a single pole. Code for all poles is included but commented out for use when needed.

fig, ax = plt.subplots(figsize = (13,6))
#ax.fill_between(CNF['Date'], CNF['Maximum_depth'], CNF['Minimum_depth'], color = "green", alpha = 0.4 )
#ax.fill_between(CNG['Date'], CNG['Maximum_depth'], CNG['Minimum_depth'], color = "red", alpha = 0.4 )
#ax.fill_between(CN20['Date'], CN20['Maximum_depth'], CN20['Minimum_depth'], color = "pink", alpha = 0.4 )
#ax.fill_between(CN50['Date'], CN50['Maximum_depth'], CN50['Minimum_depth'], color = "blue", alpha = 0.4 )
ax.fill_between(CN60['Date'], CN60['Maximum_depth'], CN60['Minimum_depth'], color = "teal", alpha = 0.4 )
#ax.fill_between(CN70['Date'], CN70['Maximum_depth'], CN70['Minimum_depth'], color = "orange", alpha = 0.4 )
#ax.fill_between(CS50['Date'], CS50['Maximum_depth'], CS50['Minimum_depth'], color = "blue", alpha = 0.4 )
#ax.fill_between(CS20['Date'], CS20['Maximum_depth'], CS20['Minimum_depth'], color = "pink", alpha = 0.4 )
#ax.fill_between(CS60['Date'], CS60['Maximum_depth'], CS60['Minimum_depth'], color = "teal", alpha = 0.4 )
#ax.fill_between(CSF['Date'], CSF['Maximum_depth'], CSF['Minimum_depth'], color = "green", alpha = 0.4 )
#ax.fill_between(CSG['Date'], CSG['Maximum_depth'], CSG['Minimum_depth'], color = "red", alpha = 0.4 )
#ax.fill_between(CS120['Date'], CS120['Maximum_depth'], CS120['Minimum_depth'], color = "orange", alpha = 0.4 )

#ax.plot(CNF['Date'], CNF['Median_depth'], label = "CN-F", color = "green")
#ax.plot(CNG['Date'], CNG['Median_depth'], label = "CN-G", color = "red")
#ax.plot(CN20['Date'], CN20['Median_depth'], label = "CN-20", color = "pink")
#ax.plot(CN50['Date'], CN50['Median_depth'], label = "CN-50", color = "blue")
ax.plot(CN60['Date'], CN60['Median_depth'], label = "CN-60", color = "teal")
#ax.plot(CN70['Date'], CN70['Median_depth'], label = "CN-70", color = "orange")
#ax.plot(CS20['Date'], CS20['Median_depth'], label = "CS-20", color = "pink")
#ax.plot(CS50['Date'], CS50['Median_depth'], label = "CS-50", color = "blue")
#ax.plot(CS60['Date'], CS60['Median_depth'], label = "CS-60", color = "teal")
#ax.plot(CSF['Date'], CSF['Median_depth'], label = "CS-F", color = "green")
#ax.plot(CSG['Date'], CSG['Median_depth'], label = "CS-G", color = "red")
#ax.plot(CS120['Date'], CS120['Median_depth'], label = "CS-120", color = "orange")


ax.set_ylim(0,110)
ax.set_xlim([datetime.date(2022, 11, 18), datetime.date(2023, 5, 14)])
ax.xaxis.set_major_formatter(dates.DateFormatter('%b-%Y'))
ax.set_ylabel("Snow Depth (cm)")
plt.legend()
plt.title("Snow Depth at Cle Elum Ridge Site CN-60 During Water Year 2023")
# Out:
# Text(0.5, 1.0, 'Snow Depth at Cle Elum Ridge Site CN-60 During Water Year 2023')

# %%
fig, ax = plt.subplots(figsize = (15,6))
N = int(CNresults['SiteOpennessAdjusted'].max())-int(CNresults['SiteOpennessAdjusted'].min())
cmap = plt.get_cmap('Blues', N)
norm = mpl.colors.Normalize(vmin=int(CNresults['SiteOpennessAdjusted'].min()), vmax=int(CNresults['SiteOpennessAdjusted'].max()))
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
#plt.colorbar(sm, ticks=[20,50,60,120], label = 'Basal Area Factor')
plt.colorbar(sm, ticks = [10,20,30,40,50,60], label = "Site Openness")

ax.plot(CN20['Date'], CN20['Pole1'], label = "CN-20-pole1", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-20-pole1",'SiteOpennessAdjusted'])))
ax.plot(CN20['Date'], CN20['Pole2'], label = "CN-20-pole2", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-20-pole2",'SiteOpennessAdjusted'])))
ax.plot(CN20['Date'], CN20['Pole3'], label = "CN-20-pole3", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-20-pole3",'SiteOpennessAdjusted'])))

ax.plot(CN50['Date'], CN50['Pole1'], label = "CN-50-pole1", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-50-pole1",'SiteOpennessAdjusted'])))
ax.plot(CN50['Date'], CN50['Pole2'], label = "CN-50-pole2", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-50-pole2",'SiteOpennessAdjusted'])))
ax.plot(CN50['Date'], CN50['Pole3'], label = "CN-50-pole3", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-50-pole3",'SiteOpennessAdjusted'])))

ax.plot(CN60['Date'], CN60['Pole1'], label = "CN-60-pole1", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-60-pole1",'SiteOpennessAdjusted'])))
ax.plot(CN60['Date'], CN60['Pole2'], label = "CN-60-pole2", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-60-pole2",'SiteOpennessAdjusted'])))
ax.plot(CN60['Date'], CN60['Pole3'], label = "CN-60-pole3", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-60-pole3",'SiteOpennessAdjusted'])))

ax.plot(CN70['Date'], CN70['Pole1'], label = "CN-70-pole1", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-70-pole1",'SiteOpennessAdjusted'])))
ax.plot(CN70['Date'], CN70['Pole2'], label = "CN-70-pole2", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-70-pole2",'SiteOpennessAdjusted'])))
ax.plot(CN70['Date'], CN70['Pole3'], label = "CN-70-pole3", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-70-pole3",'SiteOpennessAdjusted'])))

ax.plot(CNF['Date'], CNF['Pole1'], label = "CN-F-pole1", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-F-pole1",'SiteOpennessAdjusted'])))
ax.plot(CNF['Date'], CNF['Pole2'], label = "CN-F-pole2", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-F-pole2",'SiteOpennessAdjusted'])))
ax.plot(CNF['Date'], CNF['Pole3'], label = "CN-F-pole3", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-F-pole3",'SiteOpennessAdjusted'])))

ax.plot(CNG['Date'], CNG['Pole1'], label = "CN-G-pole1", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-G-pole1",'SiteOpennessAdjusted'])))
ax.plot(CNG['Date'], CNG['Pole2'], label = "CN-G-pole2", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-G-pole2",'SiteOpennessAdjusted'])))
ax.plot(CNG['Date'], CNG['Pole3'], label = "CN-G-pole3", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-G-pole3",'SiteOpennessAdjusted'])))

ax.set_ylim(0,105)
ax.set_xlim([datetime.date(2022, 11, 10), datetime.date(2023, 5, 14)])
ax.xaxis.set_major_formatter(dates.DateFormatter('%b-%Y'))
ax.set_ylabel("Snow Depth (cm)")
plt.title("Snow Depth at Cle Elum Ridge North Sites (WY 2023)")
# Out:
# C:\Users\johnc\AppData\Local\Temp\ipykernel_50460\589063337.py:8: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm, ticks = [10,20,30,40,50,60], label = "Site Openness")
# C:\Users\johnc\AppData\Local\Temp\ipykernel_50460\589063337.py:10: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   ax.plot(CN20['Date'], CN20['Pole1'], label = "CN-20-pole1", c=cmap(int(CNresults.loc[CNresults['LocationID'] == "CN-20-pole1",'SiteOpennessAdjusted'])))
# C:\Users\johnc\AppData\Local\Temp\ipykernel_50460\589063337.py:11: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
# ...

# %%
fig, ax = plt.subplots(figsize = (5,5))

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-20-pole1",'median_gapf'], CN20['Pole1'].mean(), c = 'blue', label = "North Aspect Sites", alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-20-pole2",'median_gapf'], CN20['Pole2'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-20-pole3",'median_gapf'], CN20['Pole3'].mean(), c = 'blue', alpha = 0.7)

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-50-pole1",'median_gapf'], CN50['Pole1'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-50-pole2",'median_gapf'], CN50['Pole2'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-50-pole3",'median_gapf'], CN50['Pole3'].mean(), c = 'blue', alpha = 0.7)

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-60-pole1",'median_gapf'], CN60['Pole1'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-60-pole2",'median_gapf'], CN60['Pole2'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-60-pole3",'median_gapf'], CN60['Pole3'].mean(), c = 'blue', alpha = 0.7)

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-70-pole1",'median_gapf'], CN70['Pole1'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-70-pole2",'median_gapf'], CN70['Pole2'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-70-pole3",'median_gapf'], CN70['Pole3'].mean(), c = 'blue', alpha = 0.7)

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-F-pole1",'median_gapf'], CNF['Pole1'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-F-pole2",'median_gapf'], CNF['Pole2'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-F-pole3",'median_gapf'], CNF['Pole3'].mean(), c = 'blue', alpha = 0.7)

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-G-pole1",'median_gapf'], CNG['Pole1'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-G-pole2",'median_gapf'], CNG['Pole2'].mean(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-G-pole3",'median_gapf'], CNG['Pole3'].mean(), c = 'blue', alpha = 0.7)

plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-20-pole1",'median_gapf'], CS20['Pole1'].mean(), c = 'orange', label = "South Aspect Sites", alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-20-pole2",'median_gapf'], CS20['Pole2'].mean(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-20-pole3",'median_gapf'], CS20['Pole3'].mean(), c = 'orange', alpha = 0.7)

plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-50-pole1",'median_gapf'], CS50['Pole1'].mean(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-50-pole2",'median_gapf'], CS50['Pole2'].mean(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-50-pole3",'median_gapf'], CS50['Pole3'].mean(), c = 'orange', alpha = 0.7)

plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-60-pole1",'median_gapf'], CS60['Pole1'].mean(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-60-pole2",'median_gapf'], CS60['Pole2'].mean(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-60-pole3",'median_gapf'], CS60['Pole3'].mean(), c = 'orange', alpha = 0.7)

plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-120-pole1",'median_gapf'], CS120['Pole1'].mean(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-120-pole2",'median_gapf'], CS120['Pole2'].mean(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-120-pole3",'median_gapf'], CS120['Pole3'].mean(), c = 'orange', alpha = 0.7)

plt.ylabel("Mean Snow Depth (cm)")
plt.xlabel("Gap Fraction (%)")
plt.title("Mean Snow Depth vs. Gap Fraction at Cle Elum Ridge Sites WY2023")
plt.legend()

# %%
fig, ax = plt.subplots(figsize = (5,5))

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-20-pole1",'median_gapf'], CN20['Pole1'].max(), c = 'blue', label = "North Aspect Sites", alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-20-pole2",'median_gapf'], CN20['Pole2'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-20-pole3",'median_gapf'], CN20['Pole3'].max(), c = 'blue', alpha = 0.7)

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-50-pole1",'median_gapf'], CN50['Pole1'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-50-pole2",'median_gapf'], CN50['Pole2'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-50-pole3",'median_gapf'], CN50['Pole3'].max(), c = 'blue', alpha = 0.7)

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-60-pole1",'median_gapf'], CN60['Pole1'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-60-pole2",'median_gapf'], CN60['Pole2'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-60-pole3",'median_gapf'], CN60['Pole3'].max(), c = 'blue', alpha = 0.7)

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-70-pole1",'median_gapf'], CN70['Pole1'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-70-pole2",'median_gapf'], CN70['Pole2'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-70-pole3",'median_gapf'], CN70['Pole3'].max(), c = 'blue', alpha = 0.7)

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-F-pole1",'median_gapf'], CNF['Pole1'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-F-pole2",'median_gapf'], CNF['Pole2'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-F-pole3",'median_gapf'], CNF['Pole3'].max(), c = 'blue', alpha = 0.7)

plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-G-pole1",'median_gapf'], CNG['Pole1'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-G-pole2",'median_gapf'], CNG['Pole2'].max(), c = 'blue', alpha = 0.7)
plt.scatter(CNresults.loc[CNresults['LocationID'] == "CN-G-pole3",'median_gapf'], CNG['Pole3'].max(), c = 'blue', alpha = 0.7)

plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-20-pole1",'median_gapf'], CS20['Pole1'].max(), c = 'orange', label = "South Aspect Sites", alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-20-pole2",'median_gapf'], CS20['Pole2'].max(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-20-pole3",'median_gapf'], CS20['Pole3'].max(), c = 'orange', alpha = 0.7)

plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-50-pole1",'median_gapf'], CS50['Pole1'].max(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-50-pole2",'median_gapf'], CS50['Pole2'].max(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-50-pole3",'median_gapf'], CS50['Pole3'].max(), c = 'orange', alpha = 0.7)

plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-60-pole1",'median_gapf'], CS60['Pole1'].max(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-60-pole2",'median_gapf'], CS60['Pole2'].max(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-60-pole3",'median_gapf'], CS60['Pole3'].max(), c = 'orange', alpha = 0.7)

plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-120-pole1",'median_gapf'], CS120['Pole1'].max(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-120-pole2",'median_gapf'], CS120['Pole2'].max(), c = 'orange', alpha = 0.7)
plt.scatter(CSresults.loc[CSresults['LocationID'] == "CS-120-pole3",'median_gapf'], CS120['Pole3'].max(), c = 'orange', alpha = 0.7)

plt.ylabel("Peak Snow Depth (cm)")
plt.xlabel("Gap Fraction (%)")
plt.title("Peak Snow Depth vs. Gap Fraction at Cle Elum Ridge Sites WY2023")
plt.legend()

# %%
fig, ax = plt.subplots(figsize = (15,6))
N = int(CSresults['median_gapf'].max())-int(CSresults['median_gapf'].min())
cmap = plt.get_cmap('Oranges', N)
norm = mpl.colors.Normalize(vmin=int(CSresults['median_gapf'].min()), vmax=int(CSresults['median_gapf'].max()))
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
#plt.colorbar(sm, ticks=[20,50,60,120], label = 'Basal Area Factor')
plt.colorbar(sm, ticks = [10,20,30,40,50], label = 'Gap Fraction')

ax.plot(CS20['Date'], CS20['Pole1'], label = "CS-20-pole1", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-20-pole1",'median_gapf'])))
ax.plot(CS20['Date'], CS20['Pole2'], label = "CS-20-pole2", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-20-pole2",'median_gapf'])))
ax.plot(CS20['Date'], CS20['Pole3'], label = "CS-20-pole3", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-20-pole3",'median_gapf'])))

ax.plot(CS50['Date'], CS50['Pole1'], label = "CS-50-pole1", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-50-pole1",'median_gapf'])))
ax.plot(CS50['Date'], CS50['Pole2'], label = "CS-50-pole2", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-50-pole2",'median_gapf'])))
ax.plot(CS50['Date'], CS50['Pole3'], label = "CS-50-pole3", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-50-pole3",'median_gapf'])))

ax.plot(CS60['Date'], CS60['Pole1'], label = "CS-60-pole1", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-60-pole1",'median_gapf'])))
ax.plot(CS60['Date'], CS60['Pole2'], label = "CS-60-pole2", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-60-pole2",'median_gapf'])))
ax.plot(CS60['Date'], CS60['Pole3'], label = "CS-60-pole3", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-60-pole3",'median_gapf'])))

ax.plot(CS120['Date'], CS120['Pole1'], label = "CS-120-pole1", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-120-pole1",'median_gapf'])))
ax.plot(CS120['Date'], CS120['Pole2'], label = "CS-120-pole2", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-120-pole2",'median_gapf'])))
ax.plot(CS120['Date'], CS120['Pole3'], label = "CS-120-pole3", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-120-pole3",'median_gapf'])))

# ax.plot(CSF['Date'], CSF['Pole1'], label = "CS-F-pole1", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-F-pole1",'median_gapf'])))
# ax.plot(CSF['Date'], CSF['Pole2'], label = "CS-F-pole2", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-F-pole2",'median_gapf'])))
# ax.plot(CSF['Date'], CSF['Pole3'], label = "CS-F-pole3", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-F-pole3",'median_gapf'])))

# ax.plot(CSG['Date'], CSG['Pole1'], label = "CS-G-pole1", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-G-pole1",'median_gapf'])))
# ax.plot(CSG['Date'], CSG['Pole2'], label = "CS-G-pole2", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-G-pole2",'median_gapf'])))
# ax.plot(CSG['Date'], CSG['Pole3'], label = "CS-G-pole3", c=cmap(int(CSresults.loc[CSresults['LocationID'] == "CS-G-pole3",'median_gapf'])))

ax.set_ylim(0,105)
ax.set_xlim([datetime.date(2022, 11, 10), datetime.date(2023, 5, 14)])
ax.xaxis.set_major_formatter(dates.DateFormatter('%b-%Y'))
ax.set_ylabel("Snow Depth (cm)")
plt.legend()
plt.title("Snow Depth at Cle Elum Ridge South Sites (WY 2023)")
# Out:
# Text(0.5, 1.0, 'Snow Depth at Cle Elum Ridge South Sites (WY 2023)')

# %%
CNresults_SDD3 = CNresults.loc[(CNresults['SDD1'] <= datetime.datetime(2022,12,1)) & (CNresults['SDD2'] <= datetime.datetime(2022,12,1))]
CNresults_SDD2 = CNresults.loc[(CNresults['SDD1'] <= datetime.datetime(2022,12,1)) & (CNresults['SDD2'] >= datetime.datetime(2022,12,1))]
CNresults_SDD1 = CNresults.loc[(CNresults['SDD1'] >= datetime.datetime(2022,12,1))]

fig, ax = plt.subplots(figsize = (8,4))

plt.scatter(CNresults_SDD1['median_gapf'],CNresults_SDD1['SDD1'], color = 'blue')
plt.scatter(CNresults_SDD2['median_gapf'],CNresults_SDD2['SDD2'], color = 'blue')
plt.scatter(CNresults_SDD3['median_gapf'],CNresults_SDD3['SDD3'], color = 'blue')


ax.yaxis.set_major_formatter(dates.DateFormatter('%b-%d'))
plt.xlabel("Gap Fraction")
plt.ylabel("Snow Disappearance Date")
plt.title("Snow Disappearance Date vs. Gap Fraction at Cle Elum Ridge North Sites")
# Out:
# Text(0.5, 1.0, 'Snow Disappearance Date vs. Gap Fraction at Cle Elum Ridge North Sites')

# %%
CSresults_SDD3 = CSresults.loc[(CSresults['SDD1'] <= datetime.datetime(2022,12,1)) & (CSresults['SDD2'] <= datetime.datetime(2022,12,1))]
CSresults_SDD2 = CSresults.loc[(CSresults['SDD1'] <= datetime.datetime(2022,12,1)) & (CSresults['SDD2'] >= datetime.datetime(2022,12,1))]
CSresults_SDD1 = CSresults.loc[(CSresults['SDD1'] >= datetime.datetime(2022,12,1))]

fig, ax = plt.subplots(figsize = (8,4))

plt.scatter(CSresults_SDD1['median_gapf'],CSresults_SDD1['SDD1'], color = 'orange')
plt.scatter(CSresults_SDD2['median_gapf'],CSresults_SDD2['SDD2'], color = 'orange')
plt.scatter(CSresults_SDD3['median_gapf'],CSresults_SDD3['SDD3'], color = 'orange')


ax.yaxis.set_major_formatter(dates.DateFormatter('%b-%d'))
plt.xlabel("Gap Fraction")
plt.ylabel("Snow Disappearance Date")
plt.title("Snow Disappearance Date vs. Gap Fraction at Cle Elum Ridge South Sites")
# Out:
# Text(0.5, 1.0, 'Snow Disappearance Date vs. Gap Fraction at Cle Elum Ridge South Sites')

# %%
fig, ax = plt.subplots(figsize = (8,4))

plt.scatter(CNresults_SDD1['SDD1'], CNresults_SDD1['median_gapf'], color = 'blue', alpha = 0.7, label = "North Aspect Sites")
plt.scatter(CNresults_SDD2['SDD2'], CNresults_SDD2['median_gapf'], color = 'blue', alpha = 0.7)
plt.scatter(CNresults_SDD3['SDD3'], CNresults_SDD3['median_gapf'], color = 'blue', alpha = 0.7)

plt.scatter(CSresults_SDD1['SDD1'], CSresults_SDD1['median_gapf'], color = 'orange', alpha = 0.7, label = "South Aspect Sites")
plt.scatter(CSresults_SDD2['SDD2'], CSresults_SDD2['median_gapf'], color = 'orange', alpha = 0.7)
plt.scatter(CSresults_SDD3['SDD3'], CSresults_SDD3['median_gapf'], color = 'orange', alpha = 0.7)

ax.xaxis.set_major_formatter(dates.DateFormatter('%b-%d'))
plt.ylabel("Gap Fraction")
plt.xlabel("Snow Disappearance Date")
plt.title("Snow Disappearance Date vs. Gap Fraction at Cle Elum Ridge Sites")
plt.legend(loc = "upper left")

# %%
sns.boxplot(x = results['BAF'],y = results['median_gapf'])
sns.swarmplot(x = results['BAF'],y = results['median_gapf'], color = 'black')

plt.xlabel("Basal Area Factor")
plt.ylabel("Gap Fraction (%)")
plt.title("Gap Fraction (%) vs. Basal Area Factor")
# Out:
# Text(0.5, 1.0, 'Gap Fraction (%) vs. Basal Area Factor')
